# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmate/age_gender_detector/blob/master/ROI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
foto = cv2.imread('/content/gdrive/MyDrive/Keras/Kodlar ve görüntüler/Görüntüdeki ilgi bölgesi/4 - 2 - Görüntüdeki ilgi bölgesi/maskot.jpg')

# %%
plt.imshow(foto)
plt.show()

# %%
foto = cv2.cvtColor(foto, cv2.COLOR_BGR2RGB)
plt.imshow(foto)
plt.show()

# %%
print(foto.shape)
# Out:
# (571, 800, 3)

# %%
print(foto.shape[:2])
# Out:
# (571, 800)

# %%
roi = foto[10:400, 100:450]

# %%
plt.imshow(roi)
plt.xticks([]), plt.yticks([])
plt.show()
