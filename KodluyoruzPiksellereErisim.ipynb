# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmate/age_gender_detector/blob/master/KodluyoruzPiksellereErisim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
resim1 = cv2.imread('/content/gdrive/MyDrive/Keras/Kodlar ve görüntüler/Piksellere eriƒim/4 - 1 - Piksellere eriƒim/yesilcam.jpg')

# %%
plt.imshow(resim1)
plt.show()

# %%
resim2 = cv2.cvtColor(resim1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(resim2)
plt.show()

# %%
print(resim2.shape) # Bu komut bize görüntünün ölçüsünü vermektedir.
# Out:
# (375, 624, 3)

# %%
renk = resim2[25,120]
print(renk)
# Out:
# [149 134 129]

# %%
kirmizi = resim2[25,120,0]
print('kirmizi :', kirmizi)

yesil = resim2[25,120,1]
print('yesil :', yesil)

mavi = resim2[25,120,2]
print('mavi :',mavi)
# Out:
# kirmizi : 149
# yesil : 134
# mavi : 129

# %%
resim2[25,120,1]=255
print('yeni yesil degeri:', resim2[25,120,1])
# Out:
# yeni yesil degeri: 255
